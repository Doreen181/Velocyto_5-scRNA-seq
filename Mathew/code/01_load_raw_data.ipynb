# %% [markdown]
# ## Mathew: load unprocessed Cell Ranger and salmon data

# %%
import numpy as np
import pandas as pd
import os
import scanpy as sc
import anndata as ad
from scipy.sparse import csr_matrix
from pyroe import load_fry
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib_venn import venn2
from venny4py.venny4py import *
import scvelo as scv
import re
import louvain
from skmisc.loess import loess
from skbio.diversity.alpha import simpson, gini_index
import warnings
import sys
import ensembl_rest
import time
from Ensembl_converter import EnsemblConverter

# %% [markdown]
# ## Cell Ranger

# %% [markdown]
# ### load expression matrices

# %%
# load metadata
meta = pd.read_csv("../data/metadata.csv", index_col=0)
meta
# Out:
#                     assay chemistry mouse_nr infection day_post_infection  \
# dataset
# SampleID_1_27feb19    rna        v2       M7     naive                 D0
# SampleID_2_29apr19    rna        v2       M8     naive                 D0
# SampleID_51_24feb20   rna        v2       M9  infected                 D7
# SampleID_54_24feb20   rna        v2      M10  infected                 D7
# SampleID_2_27feb19    rna        v2       M1  infected                D14
# SampleID_4_2apr19     rna        v2       M2  infected                D14
# SampleID_4_26apr19    rna        v2       M3  infected                D14
# SampleID_3_27feb19    rna        v2       M4  infected                D28
# SampleID_4_1apr19     rna        v2       M5  infected                D28
# SampleID_52_24feb20   rna        v2       M9  infected                 D7
# SampleID_55_24feb20   rna        v2      M10  infected                 D7
# SampleID_1_14mar19    rna        v2       M1  infected                D14
# SampleID_5_2apr19     rna        v2       M2  infected                D14
# SampleID_5_26apr19    rna        v2       M3  infected                D14
# SampleID_2_14mar19    rna        v2       M4  infected                D28
# SampleID_2_2apr19     rna        v2       M5  infected                D28
# SampleID_3_26apr19    rna        v2       M6  infected                D28
# SampleID_3_29apr19    rna        v2       M8     naive                 D0
# SampleID_53_24feb20   rna        v2       M9  infected                 D7
# SampleID_1_26apr19    rna        v2       M2  infected                D14
# SampleID_1_29apr19    rna        v2       M3  infected                D14
# SampleID_5_14mar19    rna        v2       M4  infected                D28
# SampleID_1_2apr19     rna        v2       M5  infected                D28
# SampleID_2_26apr19    rna        v2       M6  infected                D28
#
#                       organ organ_day
# dataset
# SampleID_1_27feb19   spleen   spleen0
# SampleID_2_29apr19   spleen   spleen0
# SampleID_51_24feb20  spleen   spleen7
# SampleID_54_24feb20  spleen   spleen7
# SampleID_2_27feb19   spleen  spleen14
# SampleID_4_2apr19    spleen  spleen14
# SampleID_4_26apr19   spleen  spleen14
# SampleID_3_27feb19   spleen  spleen28
# SampleID_4_1apr19    spleen  spleen28
# SampleID_52_24feb20     mln      mln7
# SampleID_55_24feb20     mln      mln7
# SampleID_1_14mar19      mln     mln14
# SampleID_5_2apr19       mln     mln14
# SampleID_5_26apr19      mln     mln14
# SampleID_2_14mar19      mln     mln28
# SampleID_2_2apr19       mln     mln28
# SampleID_3_26apr19      mln     mln28
# SampleID_3_29apr19     lung     lung0
# SampleID_53_24feb20    lung     lung7
# SampleID_1_26apr19     lung    lung14
# SampleID_1_29apr19     lung    lung14
# SampleID_5_14mar19     lung    lung28
# SampleID_1_2apr19      lung    lung28
# SampleID_2_26apr19     lung    lung28

# %%
adatas = []
path = "../cellranger"

for _, folders, _ in os.walk(path):
    for folder in folders:
        if folder.startswith("Sample"):

            # get adata
            adata = sc.read_10x_mtx(path + "/" + folder)
            
            # add metadata
            for col_name, col_data in meta.loc[folder].items():
                adata.obs[col_name] = col_data
    
            # add ID
            adata.obs["id"] = folder

            # rename obs names
            adata.obs_names = [bc[:-2] + "_" + folder for bc in adata.obs_names]
    
            # append to list
            adatas.append(adata)

# %%
# merge all samples
cellranger = ad.concat(adatas)
cellranger
# Out:
# AnnData object with n_obs × n_vars = 58486 × 32285
#     obs: 'assay', 'chemistry', 'mouse_nr', 'infection', 'day_post_infection', 'organ', 'organ_day', 'id'

# %%
# save
cellranger.write_h5ad("../data/mathew_cellranger_raw.h5ad")

# %% [markdown]
# ## Salmon

# %% [markdown]
# ### load expression matrices

# %%
adatas = []
path = "../salmon"

for _, folders, _ in os.walk(path):
    for folder in folders:

        if folder.startswith("SampleID"):
        
            # get adata
            adata = load_fry(path + "/" + folder + "/_quant_res", output_format = "all")
            
            # add metadata
            for col_name, col_data in meta.loc[folder].items():
                adata.obs[col_name] = col_data
    
            # add ID
            adata.obs["id"] = folder

            # rename obs names
            adata.obs_names = [bc + "_" + folder for bc in adata.obs_names]
    
            # append to list
            adatas.append(adata)
# Out:
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].
# USA mode: True
# Using pre-defined output format: all
# Will populate output field X with sum of counts frorm ['U', 'S', 'A'].

# %%
# merge all samples
salmon = ad.concat(adatas)
salmon
# Out:
# AnnData object with n_obs × n_vars = 52908 × 32285
#     obs: 'barcodes', 'assay', 'chemistry', 'mouse_nr', 'infection', 'day_post_infection', 'organ', 'organ_day', 'id'

# %%
# rename genes from ensembl ID to gene ID
e2n_path = "../../splici_references/mm10-2020-A_geneid_to_name.txt"
e2n = dict([ l.rstrip().split() for l in open(e2n_path).readlines()])
salmon.var_names = [e2n[e] for e in salmon.var_names]

# %% [markdown]
# ### add spliced, unspliced and ambiguous counts

# %%
# load alevin-fry output files using mode = raw
adatas_usa = []

for _, folders, _ in os.walk(path):
    for folder in folders:

        if folder.startswith("SampleID"):
        
            # get adata
            adata = load_fry(path + "/" + folder + "/_quant_res", output_format = "raw")
            
            # add metadata
            for col_name, col_data in meta.loc[folder].items():
                adata.obs[col_name] = col_data
    
            # add ID
            adata.obs["id"] = folder

            # rename obs names
            adata.obs_names = [bc + "_" + folder for bc in adata.obs_names]
    
            # append to list
            adatas_usa.append(adata)
# Out:
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.
# USA mode: True
# Using pre-defined output format: raw
# Will populate output field X with sum of counts frorm ['S'].
# Will combine ['S'] into output layer spliced.
# Will combine ['U'] into output layer unspliced.
# Will combine ['A'] into output layer ambiguous.

# %%
# merge all samples
usa = ad.concat(adatas_usa)
usa
# Out:
# AnnData object with n_obs × n_vars = 52908 × 32285
#     obs: 'barcodes', 'assay', 'chemistry', 'mouse_nr', 'infection', 'day_post_infection', 'organ', 'organ_day', 'id'
#     layers: 'ambiguous', 'spliced', 'unspliced'

# %%
# convert gene IDs to gene names
usa.var_names = [e2n[e] for e in usa.var_names]
usa.var_names_make_unique()

# %%
# get same bc and cell ordering as in adata object
usa = usa[salmon.obs_names, salmon.var_names]

# %%
# add spliced, unspliced, ambiguous layers to hb6
salmon.layers["spliced"] = usa.layers["spliced"]
salmon.layers["unspliced"] = usa.layers["unspliced"]
salmon.layers["ambiguous"] = usa.layers["ambiguous"]

# %%
# save
salmon.write_h5ad("../data/mathew_salmon_raw.h5ad")
